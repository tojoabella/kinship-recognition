# %% [markdown]
# # **Large-Scale Kinship Recognition Data Challenge: Kinship Verification STARTER NOTEBOOK**
#
# We provide framework code to get you started on the competition. The notebook is broken up into three main sections.
# 1. Data Loading & Visualizing
# 2. Data Generator & Model Building
# 3. Training & Testing Model
#
# We have done the majority of the heavy lifting by making the data easily and readily accessible through Google Drive. Furthermore, we have made the task easier by creating a dataloader and fully trained end-to-end model that predicts a binary label (0 or 1) denoting whether two faces share a kinship relation.

# %% [markdown]
# Mount to Google Drive

# %%
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Drive already mounted at /gdrive; to attempt to forcibly remount, call drive.mount("/gdrive", force_remount=True).

# %% [markdown]
# Install Libraries

# %%
# %%capture
# !pip install keras_vggface
# !pip install keras_applications

# %%
from collections import defaultdict
from glob import glob
from random import choice, sample

import tensorflow as tf
import keras
import cv2
from imageio import imread
from skimage.transform import resize
import numpy as np
import pandas as pd
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau
from tensorflow.keras.layers import Input, Dense, GlobalMaxPool2D, GlobalAvgPool2D, Concatenate, Multiply, Dropout, Subtract, Conv2D, Lambda, Reshape
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from keras_vggface.utils import preprocess_input
from keras_vggface.vggface import VGGFace

# %% [markdown]
# [link text](https://)train_relationships.csv contains pairs of image paths which are positive samples (related to each other).
#
# train-faces contains the images for training itself.

# %%
# !ls /gdrive/MyDrive/
# Out:
# 'Colab Notebooks'   facenet_keras_weights.h5	   tojo2.csv
#  facenet_keras.h5  'Kinship Recognition Starter'   vgg_face.h5

# %%
# Modify paths as per your method of saving them
train_file_path = "/gdrive/MyDrive/Kinship Recognition Starter/train_ds.csv"
#!ls /gdrive/MyDrive/
train_folders_path = "/gdrive/MyDrive/Kinship Recognition Starter/train/train-faces/"
# All images belonging to families F09** will be used to create the validation set while training the model
# For final submission, you can add these to the training data as well
val_famillies = "F09"

all_images = glob(train_folders_path + "*/*/*.jpg") #all images

train_images = [x for x in all_images if val_famillies not in x] #all images except for F09*
val_images = [x for x in all_images if val_famillies in x] #all images that are F09*

ppl = [x.split("/")[-3] + "/" + x.split("/")[-2] for x in all_images] #family/member/ for all images

train_person_to_images_map = defaultdict(list)
for x in train_images:
    train_person_to_images_map[x.split("/")[-3] + "/" + x.split("/")[-2]].append(x) #add a training person to map

val_person_to_images_map = defaultdict(list)
for x in val_images:
    val_person_to_images_map[x.split("/")[-3] + "/" + x.split("/")[-2]].append(x) #add a validation person to map

relationships = pd.read_csv(train_file_path)
relationships = list(zip(relationships.p1.values, relationships.p2.values, relationships.relationship.values))
relationships = [(x[0],x[1],x[2]) for x in relationships if x[0][:10] in ppl and x[1][:10] in ppl]

train = [x for x in relationships if val_famillies not in x[0]]
val = [x for x in relationships if val_famillies in x[0]]

# %%
IMG_SIZE_FN = 160
IMG_SIZE_VGG = 224

from keras.preprocessing import image

def read_img(path):
    img = image.load_img(path, target_size=(224, 224))
    img = np.array(img).astype(np.float)
    return preprocess_input(img, version=2)

'''
def read_img_vgg(path):
    img = cv2.imread(path)
    img = cv2.resize(img,(IMG_SIZE_VGG,IMG_SIZE_VGG))
    img = np.array(img).astype(np.float)
    return preprocess_input(img, version=2)

def prewhiten(x):
    if x.ndim == 4:
        axis = (1, 2, 3)
        size = x[0].size
    elif x.ndim == 3:
        axis = (0, 1, 2)
        size = x.size
    else:
        raise ValueError('Dimension should be 3 or 4')

    mean = np.mean(x, axis=axis, keepdims=True)
    std = np.std(x, axis=axis, keepdims=True)
    std_adj = np.maximum(std, 1.0/np.sqrt(size))
    y = (x - mean) / std_adj
    return y

def read_img_fn(path):
    img = cv2.imread(path)
    img = cv2.resize(img,(IMG_SIZE_FN,IMG_SIZE_FN))
    img = np.array(img).astype(np.float)
    return prewhiten(img)
'''
#list_tuples[0] = ('F0123/MID1/P01276_face0.jpg', 'F0644/MID2/P06777_face5.jpg', 0)
'''
def gen(list_tuples, person_to_images_map, batch_size=16):
    
    ppl = list(person_to_images_map.keys()) #
    while True:
        batch_tuples = sample(list_tuples, batch_size) #16 samples from list_tuples [('F0123/MID1/P01276_face0.jpg', 'F0644/MID2/P06777_face5.jpg', 0),...]
        
        # All the samples are taken from train_ds.csv, labels are in the labels column
        labels = []
        for tup in batch_tuples:
          labels.append(tup[2])
        #labels [1,0,1,1...] 16 times ---> 16 labels

        X1 = [x[0] for x in batch_tuples]
        X1 = np.array([read_img(train_folders_path + x) for x in X1])

        X1a = [x[0] for x in batch_tuples]
        X1a = np.array([read_img(train_folders_path + x) for x in X1a])

        X2 = [x[1] for x in batch_tuples]
        X2 = np.array([read_img(train_folders_path + x) for x in X2])

        X2a = [x[1] for x in batch_tuples]
        X2a = np.array([read_img(train_folders_path + x) for x in X2a])
        

        yield [X1, X2, X1a, X2a], np.array(labels)
'''

#    ppl = list(person_to_images_map.keys())
#    while True:
#        batch_tuples = sample(list_tuples, batch_size // 2)
#        labels = [1] * len(batch_tuples)
#        while len(batch_tuples) < batch_size:
#            p1 = choice(ppl)
#            p2 = choice(ppl)

#            if p1 != p2 and (p1, p2) not in list_tuples and (p2, p1) not in list_tuples:
#                batch_tuples.append((p1, p2))
#                labels.append(0)

#        for x in batch_tuples:
#            if not len(person_to_images_map[x[0]]):
#                print(x[0])

#        X1 = [choice(person_to_images_map[x[0]]) for x in batch_tuples]
#        X1 = np.array([read_img(x) for x in X1])

#        X2 = [choice(person_to_images_map[x[1]]) for x in batch_tuples]
#        X2 = np.array([read_img(x) for x in X2])

#        yield [X1, X2], labels
# Out:
# "\ndef gen(list_tuples, person_to_images_map, batch_size=16):\n    \n    ppl = list(person_to_images_map.keys()) #\n    while True:\n        batch_tuples = sample(list_tuples, batch_size) #16 samples from list_tuples [('F0123/MID1/P01276_face0.jpg', 'F0644/MID2/P06777_face5.jpg', 0),...]\n        \n        # All the samples are taken from train_ds.csv, labels are in the labels column\n        labels = []\n        for tup in batch_tuples:\n          labels.append(tup[2])\n        #labels [1,0,1,1...] 16 times ---> 16 labels\n\n        X1 = [x[0] for x in batch_tuples]\n        X1 = np.array([read_img(train_folders_path + x) for x in X1])\n\n        X1a = [x[0] for x in batch_tuples]\n        X1a = np.array([read_img(train_folders_path + x) for x in X1a])\n\n        X2 = [x[1] for x in batch_tuples]\n        X2 = np.array([read_img(train_folders_path + x) for x in X2])\n\n        X2a = [x[1] for x in batch_tuples]\n        X2a = np.array([read_img(train_folders_path + x) for x in X2a])\n        \n\n        yield [X1, X2, X1a, X2a], np.array(labels)\n"

# %%
####DO THIS GENERATOR #####
import copy
import os
def gen(list_tuples, person_to_images_map, batch_size=16):
    ppl = list(person_to_images_map.keys())
    while True:
        batch_tuples = sample(list_tuples, batch_size) #[('F0123/MID1/P01276_face0.jpg', 'F0644/MID2/P06777_face5.jpg', 0),...]
        
        labels = []
        X1 = []
        X2 = []
        for tup in batch_tuples:
            temp1 = tup[0].split('/')
            person1 = temp1[0] + '/' + temp1[1] #person1: /F0123/MID1
            temp2 = tup[1].split('/')
            person2 = temp2[0] + '/' + temp2[1] #person2: /F0123/MID1
            imgs_person1 = os.listdir(train_folders_path + person1) #imgs_person1: [P1, P2, P3...]
            imgs_person2 = os.listdir(train_folders_path + person2)
            length = len(imgs_person1)
            length = len(imgs_person2) if len(imgs_person2) < length else length
            length = min(3, length)

            for i in range(length):
                X1.append(person1 + '/' + imgs_person1[i]) #X1: [/F0123/MID1/P..., ...] 'length' times
                X2.append(person2 + '/' + imgs_person2[i])
                labels.append(tup[2])

        #X1 = [x[0] for x in batch_tuples] #x[0] = F0123/MID1/P01276_face0.jpg
        X1 = np.array([read_img(train_folders_path + x) for x in X1])
        X1a = copy.deepcopy(X1)

        #X2 = [x[1] for x in batch_tuples]
        X2 = np.array([read_img(train_folders_path + x) for x in X2])
        X2a = copy.deepcopy(X1)

        yield [X1, X2, X1a, X2a], np.array(labels)

# %% [markdown]
# Here is an ensemble model built with two resnet-50 architectures, pre-trained, with which we can apply transfer leraning on. This model achieves the baseline and the goal is to expand on this work. There have been papers exploring different architectures as well as introducing BatchNormalization among many other techniques to improve how well the model recognizes kinship between two faces.

# %%
from tensorflow.keras.layers import MaxPooling2D
from keras.models import load_model

facenet_model = load_model('facenet_keras.h5')
facenet_model.load_weights('facenet_keras_weights.h5')
for layer in facenet_model.layers[:-3]:
    layer.trainable = True
facenet_model.summary()

'''
new_layer = Dense(10, activation='softmax', name='my_dense')

inp = facenet_model.input
out = new_layer(facenet_model.layers[-1].output)

model2 = Model(inp, out)
model2.summary(line_length=150)
'''

# %%
'''
model_path = '/gdrive/MyDrive/facenet_keras.h5'
model_fn = load_model(model_path)
for layer in model_fn.layers[:-3]:
    layer.trainable = True
model_vgg = VGGFace(model='resnet50', include_top=False)
for layer in model_vgg.layers[:-3]:
    layer.trainable = True

def lol():
    input_1 = Input(shape=(IMG_SIZE_FN, IMG_SIZE_FN, 3))
    input_2 = Input(shape=(IMG_SIZE_FN, IMG_SIZE_FN, 3))
    input_3 = Input(shape=(IMG_SIZE_VGG, IMG_SIZE_VGG, 3))
    input_4 = Input(shape=(IMG_SIZE_VGG, IMG_SIZE_VGG, 3))

    x1 = model_fn(input_1)
    x2 = model_fn(input_2)
    x3 = model_vgg(input_3)
    x4 = model_vgg(input_4)
    
    x1 = Reshape((1, 1 ,128))(x1)
    x2 = Reshape((1, 1 ,128))(x2)
    x1 = Concatenate(axis=-1)([GlobalMaxPool2D()(x1), GlobalAvgPool2D()(x1)])
    x2 = Concatenate(axis=-1)([GlobalMaxPool2D()(x2), GlobalAvgPool2D()(x2)])

    x1t = Lambda(lambda tensor  : K.square(tensor))(x1)
    x2t = Lambda(lambda tensor  : K.square(tensor))(x2)
    x3t = Lambda(lambda tensor  : K.square(tensor))(x3)
    x4t = Lambda(lambda tensor  : K.square(tensor))(x4)
    
    merged_add_fn = Add()([x1, x2])
    merged_add_vgg = Add()([x3, x4])
    merged_sub1_fn = Subtract()([x1,x2])
    merged_sub1_vgg = Subtract()([x3,x4])
    merged_sub2_fn = Subtract()([x2,x1])
    merged_sub2_vgg = Subtract()([x4,x3])
    merged_mul1_fn = Multiply()([x1,x2])
    merged_mul1_vgg = Multiply()([x3,x4])
    merged_sq1_fn = Add()([x1t,x2t])
    merged_sq1_vgg = Add()([x3t,x4t])
    merged_sqrt_fn = Lambda(lambda tensor  : signed_sqrt(tensor))(merged_mul1_fn)
    merged_sqrt_vgg = Lambda(lambda tensor  : signed_sqrt(tensor))(merged_mul1_vgg)

    
    merged_add_vgg = Conv2D(128 , [1,1] )(merged_add_vgg)
    merged_sub1_vgg = Conv2D(128 , [1,1] )(merged_sub1_vgg)
    merged_sub2_vgg = Conv2D(128 , [1,1] )(merged_sub2_vgg)
    merged_mul1_vgg = Conv2D(128 , [1,1] )(merged_mul1_vgg)
    merged_sq1_vgg = Conv2D(128 , [1,1] )(merged_sq1_vgg)
    merged_sqrt_vgg = Conv2D(128 , [1,1] )(merged_sqrt_vgg)
    
    merged = Concatenate(axis=-1)([Flatten()(merged_add_vgg), (merged_add_fn), Flatten()(merged_sub1_vgg), (merged_sub1_fn),
                                   Flatten()(merged_sub2_vgg), (merged_sub2_fn), Flatten()(merged_mul1_vgg), (merged_mul1_fn), 
                                   Flatten()(merged_sq1_vgg), (merged_sq1_fn), Flatten()(merged_sqrt_vgg), (merged_sqrt_fn)])
    
    merged = Dense(100, activation="relu")(merged)
    merged = Dropout(0.1)(merged)
    merged = Dense(25, activation="relu")(merged)
    merged = Dropout(0.1)(merged)
    out = Dense(1, activation="sigmoid")(merged)

    model = Model([input_1, input_2, input_3, input_4], out)

    model.compile(loss="binary_crossentropy", metrics=['acc'], optimizer=Adam(0.00001))

    model.summary()

    return model
# Out:
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.

# %%
from tensorflow.keras.layers import Flatten, Add, BatchNormalization
from keras.models import load_model
from keras import backend as K

def signed_sqrt(x):
    return K.sign(x)*K.sqrt(K.abs(x)+1e-9)

def baseline_model():
    '''
    #FACENET
    facenet_model = load_model('/gdrive/MyDrive/facenet_keras.h5')
    for layer in facenet_model.layers[:-3]:
        layer.trainable = True
    #input
    fc_input_1 = Input(shape=(160, 160, 3))        
    fc_input_2 = Input(shape=(160, 160, 3))        
    #starting model
    fn_x1 = facenet_model(fc_input_1)
    fn_x2 = facenet_model(fc_input_2)
    #reshaping image array for global max pool layer
    fn_x1 = Reshape((1, 1 ,128))(fn_x1) 
    fn_x2 = Reshape((1, 1 ,128))(fn_x2)
    #combining inputs
    fn_x1 = Concatenate(axis=-1)([GlobalMaxPool2D()(fn_x1), GlobalAvgPool2D()(fn_x1)])
    fn_x2 = Concatenate(axis=-1)([GlobalMaxPool2D()(fn_x2), GlobalAvgPool2D()(fn_x2)])
    #adding potential features, concat to final layer before dense
    fn_add = Add()([fn_x1, fn_x2])
    fn_product = Multiply()([fn_x1,fn_x2])
    fn_x = Concatenate(axis=-1)([fn_add, fn_product])
    '''

    ###VGG###
    vgg_model = VGGFace(model='vgg16', include_top=False)
    for x in vgg_model.layers[:-3]:
        x.trainable = True
    vgg_input_1 = Input(shape=(224, 224, 3))
    vgg_input_2 = Input(shape=(224, 224, 3))
    vgg_x1 = vgg_model(vgg_input_1)
    vgg_x2 = vgg_model(vgg_input_2)
    #flatten inputs
    vgg_x1 = Concatenate(axis=-1)([GlobalMaxPool2D()(vgg_x1), GlobalAvgPool2D()(vgg_x1)])
    vgg_x2 = Concatenate(axis=-1)([GlobalMaxPool2D()(vgg_x2), GlobalAvgPool2D()(vgg_x2)])
    #adding layers
    vgg_x3 = Subtract()([vgg_x1, vgg_x2]) #substract x1 and x2
    vgg_x3 = Multiply()([vgg_x3, vgg_x3]) #then square it
    vgg_x = Multiply()([vgg_x1, vgg_x2]) #multiply x1 and x2
    vgg_x = Concatenate(axis=-1)([vgg_x, vgg_x3]) #concatenate (multiply x1 and x2) with (substract x1 and x2, then square)

    
    ###RESNET###
    res_model = VGGFace(model='resnet50', include_top=False)
    for x in res_model.layers[:-3]:
        x.trainable = True
    res_input_1 = Input(shape=(224, 224, 3)) #input tensor shape
    res_input_2 = Input(shape=(224, 224, 3))
    res_x1 = res_model(res_input_1) #reshaping input of model to that of image shapes
    res_x2 = res_model(res_input_2) #requries two resnet archs
    #flatten inputs
    res_x1 = Concatenate(axis=-1)([GlobalMaxPool2D()(res_x1), GlobalAvgPool2D()(res_x1)])
    res_x2 = Concatenate(axis=-1)([GlobalMaxPool2D()(res_x2), GlobalAvgPool2D()(res_x2)])
    #adding potential features, concat to final layer before dense
    res_x3 = Subtract()([res_x2, res_x2])
    res_x3 = Multiply()([res_x3, res_x3])
    res_x1_ = Multiply()([res_x1, res_x1])
    res_x2_ = Multiply()([res_x2, res_x2])
    res_x4 = Subtract()([res_x1_, res_x2_])
    res_x = Concatenate(axis=-1)([res_x4, res_x3])
    

    #MERGE RESNET AND VGG
    merged = Concatenate(axis=-1)([vgg_x, res_x])
    merged = Dense(200, activation="relu")(merged)
    merged = Dropout(0.01)(merged)
    out = Dense(1, activation="sigmoid")(merged)
    
    model = Model([vgg_input_1, vgg_input_2, res_input_1, res_input_2], out)
    model.compile(loss="binary_crossentropy", metrics=['acc'], optimizer=Adam(0.00001))
    '''
    def focal_loss(gamma=2., alpha=.25):
      def focal_loss_fixed(y_true, y_pred):
          pt_1 = tf.where(tf.equal(y_true, 1), y_pred, tf.ones_like(y_pred))
          pt_0 = tf.where(tf.equal(y_true, 0), y_pred, tf.zeros_like(y_pred))
          return -K.sum(alpha * K.pow(1. - pt_1, gamma) * K.log(K.epsilon()+pt_1))-K.sum((1-alpha) * K.pow( pt_0, gamma) * K.log(1. - pt_0 + K.epsilon()))
      return focal_loss_fixed
    
    model.compile(loss=[focal_loss(alpha=.25, gamma=2)], 
                  metrics=['acc'], 
                  optimizer=Adam(0.00003))
    '''
    model.summary()

    return model

# %% [markdown]
# Save the best model to your drive after each training epoch so that you can come back to it. ReduceLROnPlateau reduces the learning rate when a metric has stopped improving, in this case the validation accuracy.

# %%
file_path = "/gdrive/MyDrive/vgg_face2.h5"
checkpoint = ModelCheckpoint(file_path, monitor='val_acc', verbose=1, save_best_only=True, save_weights_only=True, mode='max')
reduce_on_plateau = ReduceLROnPlateau(monitor="val_acc", mode="max", factor=0.1, patience=20, verbose=1)
callbacks_list = [checkpoint, reduce_on_plateau]
model = baseline_model()
# Out:
# WARNING:tensorflow:
# The following Variables were used a Lambda layer's call (tf.nn.convolution_528), but
# are not present in its tracked objects:
#   <tf.Variable 'conv1_1/kernel:0' shape=(3, 3, 3, 64) dtype=float32>
# It is possible that this is intended behavior, but it is more likely
# an omission. This is a strong indication that this layer should be
# formulated as a subclassed Layer rather than a Lambda layer.
# WARNING:tensorflow:
# The following Variables were used a Lambda layer's call (tf.nn.bias_add_104), but
# are not present in its tracked objects:
#   <tf.Variable 'conv1_1/bias:0' shape=(64,) dtype=float32>
# It is possible that this is intended behavior, but it is more likely
# an omission. This is a strong indication that this layer should be
# formulated as a subclassed Layer rather than a Lambda layer.
# WARNING:tensorflow:
# The following Variables were used a Lambda layer's call (tf.nn.convolution_529), but
# are not present in its tracked objects:
#   <tf.Variable 'conv1_2/kernel:0' shape=(3, 3, 64, 64) dtype=float32>
# It is possible that this is intended behavior, but it is more likely
# an omission. This is a strong indication that this layer should be
# formulated as a subclassed Layer rather than a Lambda layer.
# WARNING:tensorflow:
# The following Variables were used a Lambda layer's call (tf.nn.bias_add_105), but
# are not present in its tracked objects:
#   <tf.Variable 'conv1_2/bias:0' shape=(64,) dtype=float32>
# It is possible that this is intended behavior, but it is more likely
# an omission. This is a strong indication that this layer should be
# formulated as a subclassed Layer rather than a Lambda layer.
# WARNING:tensorflow:
# The following Variables were used a Lambda layer's call (tf.nn.convolution_530), but
# are not present in its tracked objects:
#   <tf.Variable 'conv2_1/kernel:0' shape=(3, 3, 64, 128) dtype=float32>
# It is possible that this is intended behavior, but it is more likely
# an omission. This is a strong indication that this layer should be
# formulated as a subclassed Layer rather than a Lambda layer.
# WARNING:tensorflow:
# The following Variables were used a Lambda layer's call (tf.nn.bias_add_106), but
# are not present in its tracked objects:
#   <tf.Variable 'conv2_1/bias:0' shape=(128,) dtype=float32>
# It is possible that this is intended behavior, but it is more likely
# an omission. This is a strong indication that this layer should be
# formulated as a subclassed Layer rather than a Lambda layer.
# WARNING:tensorflow:
# The following Variables were used a Lambda layer's call (tf.nn.convolution_531), but
# are not present in its tracked objects:
#   <tf.Variable 'conv2_2/kernel:0' shape=(3, 3, 128, 128) dtype=float32>
# It is possible that this is intended behavior, but it is more likely
# an omission. This is a strong indication that this layer should be
# formulated as a subclassed Layer rather than a Lambda layer.
# WARNING:tensorflow:
# The following Variables were used a Lambda layer's call (tf.nn.bias_add_107), but
# are not present in its tracked objects:
#   <tf.Variable 'conv2_2/bias:0' shape=(128,) dtype=float32>
# It is possible that this is intended behavior, but it is more likely
# an omission. This is a strong indication that this layer should be
# formulated as a subclassed Layer rather than a Lambda layer.
# WARNING:tensorflow:
# The following Variables were used a Lambda layer's call (tf.nn.convolution_532), but
# are not present in its tracked objects:
#   <tf.Variable 'conv3_1/kernel:0' shape=(3, 3, 128, 256) dtype=float32>
# It is possible that this is intended behavior, but it is more likely
# an omission. This is a strong indication that this layer should be
# formulated as a subclassed Layer rather than a Lambda layer.
# WARNING:tensorflow:
# The following Variables were used a Lambda layer's call (tf.nn.bias_add_108), but
# are not present in its tracked objects:
#   <tf.Variable 'conv3_1/bias:0' shape=(256,) dtype=float32>
# It is possible that this is intended behavior, but it is more likely
# an omission. This is a strong indication that this layer should be
# formulated as a subclassed Layer rather than a Lambda layer.
# WARNING:tensorflow:
# The following Variables were used a Lambda layer's call (tf.nn.convolution_533), but
# are not present in its tracked objects:
#   <tf.Variable 'conv3_2/kernel:0' shape=(3, 3, 256, 256) dtype=float32>
# It is possible that this is intended behavior, but it is more likely
# an omission. This is a strong indication that this layer should be
# formulated as a subclassed Layer rather than a Lambda layer.
# WARNING:tensorflow:
# The following Variables were used a Lambda layer's call (tf.nn.bias_add_109), but
# are not present in its tracked objects:
#   <tf.Variable 'conv3_2/bias:0' shape=(256,) dtype=float32>
# It is possible that this is intended behavior, but it is more likely
# an omission. This is a strong indication that this layer should be
# formulated as a subclassed Layer rather than a Lambda layer.
# WARNING:tensorflow:
# The following Variables were used a Lambda layer's call (tf.nn.convolution_534), but
# are not present in its tracked objects:
#   <tf.Variable 'conv3_3/kernel:0' shape=(3, 3, 256, 256) dtype=float32>
# It is possible that this is intended behavior, but it is more likely
# an omission. This is a strong indication that this layer should be
# formulated as a subclassed Layer rather than a Lambda layer.
# WARNING:tensorflow:
# The following Variables were used a Lambda layer's call (tf.nn.bias_add_110), but
# are not present in its tracked objects:
#   <tf.Variable 'conv3_3/bias:0' shape=(256,) dtype=float32>
# It is possible that this is intended behavior, but it is more likely
# an omission. This is a strong indication that this layer should be
# formulated as a subclassed Layer rather than a Lambda layer.
# WARNING:tensorflow:
# The following Variables were used a Lambda layer's call (tf.nn.convolution_535), but
# are not present in its tracked objects:
#   <tf.Variable 'conv4_1/kernel:0' shape=(3, 3, 256, 512) dtype=float32>
# It is possible that this is intended behavior, but it is more likely
# an omission. This is a strong indication that this layer should be
# formulated as a subclassed Layer rather than a Lambda layer.
# WARNING:tensorflow:
# The following Variables were used a Lambda layer's call (tf.nn.bias_add_111), but
# are not present in its tracked objects:
#   <tf.Variable 'conv4_1/bias:0' shape=(512,) dtype=float32>
# It is possible that this is intended behavior, but it is more likely
# an omission. This is a strong indication that this layer should be
# formulated as a subclassed Layer rather than a Lambda layer.
# WARNING:tensorflow:
# The following Variables were used a Lambda layer's call (tf.nn.convolution_536), but
# are not present in its tracked objects:
#   <tf.Variable 'conv4_2/kernel:0' shape=(3, 3, 512, 512) dtype=float32>
# It is possible that this is intended behavior, but it is more likely
# an omission. This is a strong indication that this layer should be
# formulated as a subclassed Layer rather than a Lambda layer.
# WARNING:tensorflow:
# The following Variables were used a Lambda layer's call (tf.nn.bias_add_112), but
# are not present in its tracked objects:
#   <tf.Variable 'conv4_2/bias:0' shape=(512,) dtype=float32>
# It is possible that this is intended behavior, but it is more likely
# an omission. This is a strong indication that this layer should be
# formulated as a subclassed Layer rather than a Lambda layer.
# WARNING:tensorflow:
# The following Variables were used a Lambda layer's call (tf.nn.convolution_537), but
# are not present in its tracked objects:
#   <tf.Variable 'conv4_3/kernel:0' shape=(3, 3, 512, 512) dtype=float32>
# It is possible that this is intended behavior, but it is more likely
# an omission. This is a strong indication that this layer should be
# formulated as a subclassed Layer rather than a Lambda layer.
# WARNING:tensorflow:
# The following Variables were used a Lambda layer's call (tf.nn.bias_add_113), but
# are not present in its tracked objects:
#   <tf.Variable 'conv4_3/bias:0' shape=(512,) dtype=float32>
# It is possible that this is intended behavior, but it is more likely
# an omission. This is a strong indication that this layer should be
# formulated as a subclassed Layer rather than a Lambda layer.
# WARNING:tensorflow:
# The following Variables were used a Lambda layer's call (tf.nn.convolution_538), but
# are not present in its tracked objects:
#   <tf.Variable 'conv5_1/kernel:0' shape=(3, 3, 512, 512) dtype=float32>
# It is possible that this is intended behavior, but it is more likely
# an omission. This is a strong indication that this layer should be
# formulated as a subclassed Layer rather than a Lambda layer.
# WARNING:tensorflow:
# The following Variables were used a Lambda layer's call (tf.nn.bias_add_114), but
# are not present in its tracked objects:
#   <tf.Variable 'conv5_1/bias:0' shape=(512,) dtype=float32>
# It is possible that this is intended behavior, but it is more likely
# an omission. This is a strong indication that this layer should be
# formulated as a subclassed Layer rather than a Lambda layer.
# WARNING:tensorflow:
# The following Variables were used a Lambda layer's call (tf.nn.convolution_539), but
# are not present in its tracked objects:
#   <tf.Variable 'conv5_2/kernel:0' shape=(3, 3, 512, 512) dtype=float32>
# It is possible that this is intended behavior, but it is more likely
# an omission. This is a strong indication that this layer should be
# formulated as a subclassed Layer rather than a Lambda layer.
# WARNING:tensorflow:
# The following Variables were used a Lambda layer's call (tf.nn.bias_add_115), but
# are not present in its tracked objects:
#   <tf.Variable 'conv5_2/bias:0' shape=(512,) dtype=float32>
# It is possible that this is intended behavior, but it is more likely
# an omission. This is a strong indication that this layer should be
# formulated as a subclassed Layer rather than a Lambda layer.
# WARNING:tensorflow:
# The following Variables were used a Lambda layer's call (tf.nn.convolution_540), but
# are not present in its tracked objects:
#   <tf.Variable 'conv5_3/kernel:0' shape=(3, 3, 512, 512) dtype=float32>
# It is possible that this is intended behavior, but it is more likely
# an omission. This is a strong indication that this layer should be
# formulated as a subclassed Layer rather than a Lambda layer.
# WARNING:tensorflow:
# The following Variables were used a Lambda layer's call (tf.nn.bias_add_116), but
# are not present in its tracked objects:
#   <tf.Variable 'conv5_3/bias:0' shape=(512,) dtype=float32>
# It is possible that this is intended behavior, but it is more likely
# an omission. This is a strong indication that this layer should be
# formulated as a subclassed Layer rather than a Lambda layer.
# WARNING:tensorflow:
# The following Variables were used a Lambda layer's call (tf.nn.convolution_541), but
# are not present in its tracked objects:
#   <tf.Variable 'conv1_1/kernel:0' shape=(3, 3, 3, 64) dtype=float32>
# It is possible that this is intended behavior, but it is more likely
# an omission. This is a strong indication that this layer should be
# formulated as a subclassed Layer rather than a Lambda layer.
# WARNING:tensorflow:
# The following Variables were used a Lambda layer's call (tf.nn.bias_add_117), but
# are not present in its tracked objects:
#   <tf.Variable 'conv1_1/bias:0' shape=(64,) dtype=float32>
# It is possible that this is intended behavior, but it is more likely
# an omission. This is a strong indication that this layer should be
# formulated as a subclassed Layer rather than a Lambda layer.
# WARNING:tensorflow:
# The following Variables were used a Lambda layer's call (tf.nn.convolution_542), but
# are not present in its tracked objects:
#   <tf.Variable 'conv1_2/kernel:0' shape=(3, 3, 64, 64) dtype=float32>
# It is possible that this is intended behavior, but it is more likely
# an omission. This is a strong indication that this layer should be
# formulated as a subclassed Layer rather than a Lambda layer.
# WARNING:tensorflow:
# The following Variables were used a Lambda layer's call (tf.nn.bias_add_118), but
# are not present in its tracked objects:
#   <tf.Variable 'conv1_2/bias:0' shape=(64,) dtype=float32>
# It is possible that this is intended behavior, but it is more likely
# an omission. This is a strong indication that this layer should be
# formulated as a subclassed Layer rather than a Lambda layer.
# WARNING:tensorflow:
# The following Variables were used a Lambda layer's call (tf.nn.convolution_543), but
# are not present in its tracked objects:
#   <tf.Variable 'conv2_1/kernel:0' shape=(3, 3, 64, 128) dtype=float32>
# It is possible that this is intended behavior, but it is more likely
# an omission. This is a strong indication that this layer should be
# formulated as a subclassed Layer rather than a Lambda layer.
# WARNING:tensorflow:
# The following Variables were used a Lambda layer's call (tf.nn.bias_add_119), but
# are not present in its tracked objects:
#   <tf.Variable 'conv2_1/bias:0' shape=(128,) dtype=float32>
# It is possible that this is intended behavior, but it is more likely
# an omission. This is a strong indication that this layer should be
# formulated as a subclassed Layer rather than a Lambda layer.
# WARNING:tensorflow:
# The following Variables were used a Lambda layer's call (tf.nn.convolution_544), but
# are not present in its tracked objects:
#   <tf.Variable 'conv2_2/kernel:0' shape=(3, 3, 128, 128) dtype=float32>
# It is possible that this is intended behavior, but it is more likely
# an omission. This is a strong indication that this layer should be
# formulated as a subclassed Layer rather than a Lambda layer.
# WARNING:tensorflow:
# The following Variables were used a Lambda layer's call (tf.nn.bias_add_120), but
# are not present in its tracked objects:
#   <tf.Variable 'conv2_2/bias:0' shape=(128,) dtype=float32>
# It is possible that this is intended behavior, but it is more likely
# an omission. This is a strong indication that this layer should be
# formulated as a subclassed Layer rather than a Lambda layer.
# WARNING:tensorflow:
# The following Variables were used a Lambda layer's call (tf.nn.convolution_545), but
# are not present in its tracked objects:
#   <tf.Variable 'conv3_1/kernel:0' shape=(3, 3, 128, 256) dtype=float32>
# It is possible that this is intended behavior, but it is more likely
# an omission. This is a strong indication that this layer should be
# formulated as a subclassed Layer rather than a Lambda layer.
# WARNING:tensorflow:
# The following Variables were used a Lambda layer's call (tf.nn.bias_add_121), but
# are not present in its tracked objects:
#   <tf.Variable 'conv3_1/bias:0' shape=(256,) dtype=float32>
# It is possible that this is intended behavior, but it is more likely
# an omission. This is a strong indication that this layer should be
# formulated as a subclassed Layer rather than a Lambda layer.
# WARNING:tensorflow:
# The following Variables were used a Lambda layer's call (tf.nn.convolution_546), but
# are not present in its tracked objects:
#   <tf.Variable 'conv3_2/kernel:0' shape=(3, 3, 256, 256) dtype=float32>
# It is possible that this is intended behavior, but it is more likely
# an omission. This is a strong indication that this layer should be
# formulated as a subclassed Layer rather than a Lambda layer.
# WARNING:tensorflow:
# The following Variables were used a Lambda layer's call (tf.nn.bias_add_122), but
# are not present in its tracked objects:
#   <tf.Variable 'conv3_2/bias:0' shape=(256,) dtype=float32>
# It is possible that this is intended behavior, but it is more likely
# an omission. This is a strong indication that this layer should be
# formulated as a subclassed Layer rather than a Lambda layer.
# WARNING:tensorflow:
# The following Variables were used a Lambda layer's call (tf.nn.convolution_547), but
# are not present in its tracked objects:
#   <tf.Variable 'conv3_3/kernel:0' shape=(3, 3, 256, 256) dtype=float32>
# It is possible that this is intended behavior, but it is more likely
# an omission. This is a strong indication that this layer should be
# formulated as a subclassed Layer rather than a Lambda layer.
# WARNING:tensorflow:
# The following Variables were used a Lambda layer's call (tf.nn.bias_add_123), but
# are not present in its tracked objects:
#   <tf.Variable 'conv3_3/bias:0' shape=(256,) dtype=float32>
# It is possible that this is intended behavior, but it is more likely
# an omission. This is a strong indication that this layer should be
# formulated as a subclassed Layer rather than a Lambda layer.
# WARNING:tensorflow:
# The following Variables were used a Lambda layer's call (tf.nn.convolution_548), but
# are not present in its tracked objects:
#   <tf.Variable 'conv4_1/kernel:0' shape=(3, 3, 256, 512) dtype=float32>
# It is possible that this is intended behavior, but it is more likely
# an omission. This is a strong indication that this layer should be
# formulated as a subclassed Layer rather than a Lambda layer.
# WARNING:tensorflow:
# The following Variables were used a Lambda layer's call (tf.nn.bias_add_124), but
# are not present in its tracked objects:
#   <tf.Variable 'conv4_1/bias:0' shape=(512,) dtype=float32>
# It is possible that this is intended behavior, but it is more likely
# an omission. This is a strong indication that this layer should be
# formulated as a subclassed Layer rather than a Lambda layer.
# WARNING:tensorflow:
# The following Variables were used a Lambda layer's call (tf.nn.convolution_549), but
# are not present in its tracked objects:
#   <tf.Variable 'conv4_2/kernel:0' shape=(3, 3, 512, 512) dtype=float32>
# It is possible that this is intended behavior, but it is more likely
# an omission. This is a strong indication that this layer should be
# formulated as a subclassed Layer rather than a Lambda layer.
# WARNING:tensorflow:
# The following Variables were used a Lambda layer's call (tf.nn.bias_add_125), but
# are not present in its tracked objects:
#   <tf.Variable 'conv4_2/bias:0' shape=(512,) dtype=float32>
# It is possible that this is intended behavior, but it is more likely
# an omission. This is a strong indication that this layer should be
# formulated as a subclassed Layer rather than a Lambda layer.
# WARNING:tensorflow:
# The following Variables were used a Lambda layer's call (tf.nn.convolution_550), but
# are not present in its tracked objects:
#   <tf.Variable 'conv4_3/kernel:0' shape=(3, 3, 512, 512) dtype=float32>
# It is possible that this is intended behavior, but it is more likely
# an omission. This is a strong indication that this layer should be
# formulated as a subclassed Layer rather than a Lambda layer.
# WARNING:tensorflow:
# The following Variables were used a Lambda layer's call (tf.nn.bias_add_126), but
# are not present in its tracked objects:
#   <tf.Variable 'conv4_3/bias:0' shape=(512,) dtype=float32>
# It is possible that this is intended behavior, but it is more likely
# an omission. This is a strong indication that this layer should be
# formulated as a subclassed Layer rather than a Lambda layer.
# WARNING:tensorflow:
# The following Variables were used a Lambda layer's call (tf.nn.convolution_551), but
# are not present in its tracked objects:
#   <tf.Variable 'conv5_1/kernel:0' shape=(3, 3, 512, 512) dtype=float32>
# It is possible that this is intended behavior, but it is more likely
# an omission. This is a strong indication that this layer should be
# formulated as a subclassed Layer rather than a Lambda layer.
# WARNING:tensorflow:
# The following Variables were used a Lambda layer's call (tf.nn.bias_add_127), but
# are not present in its tracked objects:
#   <tf.Variable 'conv5_1/bias:0' shape=(512,) dtype=float32>
# It is possible that this is intended behavior, but it is more likely
# an omission. This is a strong indication that this layer should be
# formulated as a subclassed Layer rather than a Lambda layer.
# WARNING:tensorflow:
# The following Variables were used a Lambda layer's call (tf.nn.convolution_552), but
# are not present in its tracked objects:
#   <tf.Variable 'conv5_2/kernel:0' shape=(3, 3, 512, 512) dtype=float32>
# It is possible that this is intended behavior, but it is more likely
# an omission. This is a strong indication that this layer should be
# formulated as a subclassed Layer rather than a Lambda layer.
# WARNING:tensorflow:
# The following Variables were used a Lambda layer's call (tf.nn.bias_add_128), but
# are not present in its tracked objects:
#   <tf.Variable 'conv5_2/bias:0' shape=(512,) dtype=float32>
# It is possible that this is intended behavior, but it is more likely
# an omission. This is a strong indication that this layer should be
# formulated as a subclassed Layer rather than a Lambda layer.
# WARNING:tensorflow:
# The following Variables were used a Lambda layer's call (tf.nn.convolution_553), but
# are not present in its tracked objects:
#   <tf.Variable 'conv5_3/kernel:0' shape=(3, 3, 512, 512) dtype=float32>
# It is possible that this is intended behavior, but it is more likely
# an omission. This is a strong indication that this layer should be
# formulated as a subclassed Layer rather than a Lambda layer.
# WARNING:tensorflow:
# The following Variables were used a Lambda layer's call (tf.nn.bias_add_129), but
# are not present in its tracked objects:
#   <tf.Variable 'conv5_3/bias:0' shape=(512,) dtype=float32>
# It is possible that this is intended behavior, but it is more likely
# an omission. This is a strong indication that this layer should be
# formulated as a subclassed Layer rather than a Lambda layer.
# WARNING:tensorflow:
# The following Variables were used a Lambda layer's call (tf.nn.convolution_554), but
# are not present in its tracked objects:
#   <tf.Variable 'conv1/7x7_s2/kernel:0' shape=(7, 7, 3, 64) dtype=float32>
# It is possible that this is intended behavior, but it is more likely
# an omission. This is a strong indication that this layer should be
# formulated as a subclassed Layer rather than a Lambda layer.
# WARNING:tensorflow:
# The following Variables were used a Lambda layer's call (tf.compat.v1.nn.fused_batch_norm_424), but
# are not present in its tracked objects:
#   <tf.Variable 'conv1/7x7_s2/bn/gamma:0' shape=(64,) dtype=float32>
#   <tf.Variable 'conv1/7x7_s2/bn/beta:0' shape=(64,) dtype=float32>
# It is possible that this is intended behavior, but it is more likely
# an omission. This is a strong indication that this layer should be
# formulated as a subclassed Layer rather than a Lambda layer.
# WARNING:tensorflow:
# The following Variables were used a Lambda layer's call (tf.nn.convolution_555), but
# are not present in its tracked objects:
#   <tf.Variable 'conv2_1_1x1_reduce/kernel:0' shape=(1, 1, 64, 64) dtype=float32>
# It is possible that this is intended behavior, but it is more likely
# an omission. This is a strong indication that this layer should be
# formulated as a subclassed Layer rather than a Lambda layer.
# WARNING:tensorflow:
# The following Variables were used a Lambda layer's call (tf.compat.v1.nn.fused_batch_norm_425), but
# are not present in its tracked objects:
#   <tf.Variable 'conv2_1_1x1_reduce/bn/gamma:0' shape=(64,) dtype=float32>
#   <tf.Variable 'conv2_1_1x1_reduce/bn/beta:0' shape=(64,) dtype=float32>
# It is possible that this is intended behavior, but it is more likely
# an omission. This is a strong indication that this layer should be
# formulated as a subclassed Layer rather than a Lambda layer.
# WARNING:tensorflow:
# The following Variables were used a Lambda layer's call (tf.nn.convolution_556), but
# are not present in its tracked objects:
#   <tf.Variable 'conv2_1_3x3/kernel:0' shape=(3, 3, 64, 64) dtype=float32>
# It is possible that this is intended behavior, but it is more likely
# an omission. This is a strong indication that this layer should be
# formulated as a subclassed Layer rather than a Lambda layer.
# WARNING:tensorflow:
# The following Variables were used a Lambda layer's call (tf.compat.v1.nn.fused_batch_norm_426), but
# are not present in its tracked objects:
#   <tf.Variable 'conv2_1_3x3/bn/gamma:0' shape=(64,) dtype=float32>
#   <tf.Variable 'conv2_1_3x3/bn/beta:0' shape=(64,) dtype=float32>
# It is possible that this is intended behavior, but it is more likely
# an omission. This is a strong indication that this layer should be
# formulated as a subclassed Layer rather than a Lambda layer.
# WARNING:tensorflow:
# The following Variables were used a Lambda layer's call (tf.nn.convolution_557), but
# are not present in its tracked objects:
#   <tf.Variable 'conv2_1_1x1_proj/kernel:0' shape=(1, 1, 64, 256) dtype=float32>
# It is possible that this is intended behavior, but it is more likely
# an omission. This is a strong indication that this layer should be
# formulated as a subclassed Layer rather than a Lambda layer.
# WARNING:tensorflow:
# The following Variables were used a Lambda layer's call (tf.nn.convolution_558), but
# are not present in its tracked objects:
#   <tf.Variable 'conv2_1_1x1_increase/kernel:0' shape=(1, 1, 64, 256) dtype=float32>
# It is possible that this is intended behavior, but it is more likely
# an omission. This is a strong indication that this layer should be
# formulated as a subclassed Layer rather than a Lambda layer.
# WARNING:tensorflow:
# The following Variables were used a Lambda layer's call (tf.compat.v1.nn.fused_batch_norm_427), but
# are not present in its tracked objects:
#   <tf.Variable 'conv2_1_1x1_increase/bn/gamma:0' shape=(256,) dtype=float32>
#   <tf.Variable 'conv2_1_1x1_increase/bn/beta:0' shape=(256,) dtype=float32>
# It is possible that this is intended behavior, but it is more likely
# an omission. This is a strong indication that this layer should be
# formulated as a subclassed Layer rather than a Lambda layer.
# WARNING:tensorflow:
# The following Variables were used a Lambda layer's call (tf.compat.v1.nn.fused_batch_norm_428), but
# are not present in its tracked objects:
#   <tf.Variable 'conv2_1_1x1_proj/bn/gamma:0' shape=(256,) dtype=float32>
#   <tf.Variable 'conv2_1_1x1_proj/bn/beta:0' shape=(256,) dtype=float32>
# It is possible that this is intended behavior, but it is more likely
# an omission. This is a strong indication that this layer should be
# formulated as a subclassed Layer rather than a Lambda layer.
# WARNING:tensorflow:
# The following Variables were used a Lambda layer's call (tf.nn.convolution_559), but
# are not present in its tracked objects:
#   <tf.Variable 'conv2_2_1x1_reduce/kernel:0' shape=(1, 1, 256, 64) dtype=float32>
# It is possible that this is intended behavior, but it is more likely
# an omission. This is a strong indication that this layer should be
# formulated as a subclassed Layer rather than a Lambda layer.
# WARNING:tensorflow:
# The following Variables were used a Lambda layer's call (tf.compat.v1.nn.fused_batch_norm_429), but
# are not present in its tracked objects:
#   <tf.Variable 'conv2_2_1x1_reduce/bn/gamma:0' shape=(64,) dtype=float32>
#   <tf.Variable 'conv2_2_1x1_reduce/bn/beta:0' shape=(64,) dtype=float32>
# It is possible that this is intended behavior, but it is more likely
# an omission. This is a strong indication that this layer should be
# formulated as a subclassed Layer rather than a Lambda layer.
# WARNING:tensorflow:
# The following Variables were used a Lambda layer's call (tf.nn.convolution_560), but
# are not present in its tracked objects:
#   <tf.Variable 'conv2_2_3x3/kernel:0' shape=(3, 3, 64, 64) dtype=float32>
# It is possible that this is intended behavior, but it is more likely
# an omission. This is a strong indication that this layer should be
# formulated as a subclassed Layer rather than a Lambda layer.
# WARNING:tensorflow:
# The following Variables were used a Lambda layer's call (tf.compat.v1.nn.fused_batch_norm_430), but
# are not present in its tracked objects:
#   <tf.Variable 'conv2_2_3x3/bn/gamma:0' shape=(64,) dtype=float32>
#   <tf.Variable 'conv2_2_3x3/bn/beta:0' shape=(64,) dtype=float32>
# It is possible that this is intended behavior, but it is more likely
# an omission. This is a strong indication that this layer should be
# formulated as a subclassed Layer rather than a Lambda layer.
# WARNING:tensorflow:
# The following Variables were used a Lambda layer's call (tf.nn.convolution_561), but
# are not present in its tracked objects:
#   <tf.Variable 'conv2_2_1x1_increase/kernel:0' shape=(1, 1, 64, 256) dtype=float32>
# It is possible that this is intended behavior, but it is more likely
# an omission. This is a strong indication that this layer should be
# formulated as a subclassed Layer rather than a Lambda layer.
# WARNING:tensorflow:
# The following Variables were used a Lambda layer's call (tf.compat.v1.nn.fused_batch_norm_431), but
# are not present in its tracked objects:
#   <tf.Variable 'conv2_2_1x1_increase/bn/gamma:0' shape=(256,) dtype=float32>
#   <tf.Variable 'conv2_2_1x1_increase/bn/beta:0' shape=(256,) dtype=float32>
# It is possible that this is intended behavior, but it is more likely
# an omission. This is a strong indication that this layer should be
# formulated as a subclassed Layer rather than a Lambda layer.
# WARNING:tensorflow:
# The following Variables were used a Lambda layer's call (tf.nn.convolution_562), but
# are not present in its tracked objects:
#   <tf.Variable 'conv2_3_1x1_reduce/kernel:0' shape=(1, 1, 256, 64) dtype=float32>
# It is possible that this is intended behavior, but it is more likely
# an omission. This is a strong indication that this layer should be
# formulated as a subclassed Layer rather than a Lambda layer.
# WARNING:tensorflow:
# The following Variables were used a Lambda layer's call (tf.compat.v1.nn.fused_batch_norm_432), but
# are not present in its tracked objects:
#   <tf.Variable 'conv2_3_1x1_reduce/bn/gamma:0' shape=(64,) dtype=float32>
#   <tf.Variable 'conv2_3_1x1_reduce/bn/beta:0' shape=(64,) dtype=float32>
# It is possible that this is intended behavior, but it is more likely
# an omission. This is a strong indication that this layer should be
# formulated as a subclassed Layer rather than a Lambda layer.
# WARNING:tensorflow:
# The following Variables were used a Lambda layer's call (tf.nn.convolution_563), but
# are not present in its tracked objects:
#   <tf.Variable 'conv2_3_3x3/kernel:0' shape=(3, 3, 64, 64) dtype=float32>
# It is possible that this is intended behavior, but it is more likely
# an omission. This is a strong indication that this layer should be
# formulated as a subclassed Layer rather than a Lambda layer.
# WARNING:tensorflow:
# The following Variables were used a Lambda layer's call (tf.compat.v1.nn.fused_batch_norm_433), but
# are not present in its tracked objects:
#   <tf.Variable 'conv2_3_3x3/bn/gamma:0' shape=(64,) dtype=float32>
#   <tf.Variable 'conv2_3_3x3/bn/beta:0' shape=(64,) dtype=float32>
# It is possible that this is intended behavior, but it is more likely
# an omission. This is a strong indication that this layer should be
# formulated as a subclassed Layer rather than a Lambda layer.
# WARNING:tensorflow:
# The following Variables were used a Lambda layer's call (tf.nn.convolution_564), but
# are not present in its tracked objects:
#   <tf.Variable 'conv2_3_1x1_increase/kernel:0' shape=(1, 1, 64, 256) dtype=float32>
# It is possible that this is intended behavior, but it is more likely
# an omission. This is a strong indication that this layer should be
# formulated as a subclassed Layer rather than a Lambda layer.
# WARNING:tensorflow:
# The following Variables were used a Lambda layer's call (tf.compat.v1.nn.fused_batch_norm_434), but
# are not present in its tracked objects:
#   <tf.Variable 'conv2_3_1x1_increase/bn/gamma:0' shape=(256,) dtype=float32>
#   <tf.Variable 'conv2_3_1x1_increase/bn/beta:0' shape=(256,) dtype=float32>
# It is possible that this is intended behavior, but it is more likely
# an omission. This is a strong indication that this layer should be
# formulated as a subclassed Layer rather than a Lambda layer.
# WARNING:tensorflow:
# The following Variables were used a Lambda layer's call (tf.nn.convolution_565), but
# are not present in its tracked objects:
#   <tf.Variable 'conv3_1_1x1_reduce/kernel:0' shape=(1, 1, 256, 128) dtype=float32>
# It is possible that this is intended behavior, but it is more likely
# an omission. This is a strong indication that this layer should be
# formulated as a subclassed Layer rather than a Lambda layer.
# WARNING:tensorflow:
# The following Variables were used a Lambda layer's call (tf.compat.v1.nn.fused_batch_norm_435), but
# are not present in its tracked objects:
#   <tf.Variable 'conv3_1_1x1_reduce/bn/gamma:0' shape=(128,) dtype=float32>
#   <tf.Variable 'conv3_1_1x1_reduce/bn/beta:0' shape=(128,) dtype=float32>
# It is possible that this is intended behavior, but it is more likely
# an omission. This is a strong indication that this layer should be
# formulated as a subclassed Layer rather than a Lambda layer.
# WARNING:tensorflow:
# The following Variables were used a Lambda layer's call (tf.nn.convolution_566), but
# are not present in its tracked objects:
#   <tf.Variable 'conv3_1_3x3/kernel:0' shape=(3, 3, 128, 128) dtype=float32>
# It is possible that this is intended behavior, but it is more likely
# an omission. This is a strong indication that this layer should be
# formulated as a subclassed Layer rather than a Lambda layer.
# WARNING:tensorflow:
# The following Variables were used a Lambda layer's call (tf.compat.v1.nn.fused_batch_norm_436), but
# are not present in its tracked objects:
#   <tf.Variable 'conv3_1_3x3/bn/gamma:0' shape=(128,) dtype=float32>
#   <tf.Variable 'conv3_1_3x3/bn/beta:0' shape=(128,) dtype=float32>
# It is possible that this is intended behavior, but it is more likely
# an omission. This is a strong indication that this layer should be
# formulated as a subclassed Layer rather than a Lambda layer.
# WARNING:tensorflow:
# The following Variables were used a Lambda layer's call (tf.nn.convolution_567), but
# are not present in its tracked objects:
#   <tf.Variable 'conv3_1_1x1_proj/kernel:0' shape=(1, 1, 256, 512) dtype=float32>
# It is possible that this is intended behavior, but it is more likely
# an omission. This is a strong indication that this layer should be
# formulated as a subclassed Layer rather than a Lambda layer.
# WARNING:tensorflow:
# The following Variables were used a Lambda layer's call (tf.nn.convolution_568), but
# are not present in its tracked objects:
#   <tf.Variable 'conv3_1_1x1_increase/kernel:0' shape=(1, 1, 128, 512) dtype=float32>
# It is possible that this is intended behavior, but it is more likely
# an omission. This is a strong indication that this layer should be
# formulated as a subclassed Layer rather than a Lambda layer.
# WARNING:tensorflow:
# The following Variables were used a Lambda layer's call (tf.compat.v1.nn.fused_batch_norm_437), but
# are not present in its tracked objects:
#   <tf.Variable 'conv3_1_1x1_increase/bn/gamma:0' shape=(512,) dtype=float32>
#   <tf.Variable 'conv3_1_1x1_increase/bn/beta:0' shape=(512,) dtype=float32>
# It is possible that this is intended behavior, but it is more likely
# an omission. This is a strong indication that this layer should be
# formulated as a subclassed Layer rather than a Lambda layer.
# WARNING:tensorflow:
# The following Variables were used a Lambda layer's call (tf.compat.v1.nn.fused_batch_norm_438), but
# are not present in its tracked objects:
#   <tf.Variable 'conv3_1_1x1_proj/bn/gamma:0' shape=(512,) dtype=float32>
#   <tf.Variable 'conv3_1_1x1_proj/bn/beta:0' shape=(512,) dtype=float32>
# It is possible that this is intended behavior, but it is more likely
# an omission. This is a strong indication that this layer should be
# formulated as a subclassed Layer rather than a Lambda layer.
# WARNING:tensorflow:
# The following Variables were used a Lambda layer's call (tf.nn.convolution_569), but
# are not present in its tracked objects:
#   <tf.Variable 'conv3_2_1x1_reduce/kernel:0' shape=(1, 1, 512, 128) dtype=float32>
# It is possible that this is intended behavior, but it is more likely
# an omission. This is a strong indication that this layer should be
# formulated as a subclassed Layer rather than a Lambda layer.
# WARNING:tensorflow:
# The following Variables were used a Lambda layer's call (tf.compat.v1.nn.fused_batch_norm_439), but
# are not present in its tracked objects:
#   <tf.Variable 'conv3_2_1x1_reduce/bn/gamma:0' shape=(128,) dtype=float32>
#   <tf.Variable 'conv3_2_1x1_reduce/bn/beta:0' shape=(128,) dtype=float32>
# It is possible that this is intended behavior, but it is more likely
# an omission. This is a strong indication that this layer should be
# formulated as a subclassed Layer rather than a Lambda layer.
# WARNING:tensorflow:
# The following Variables were used a Lambda layer's call (tf.nn.convolution_570), but
# are not present in its tracked objects:
#   <tf.Variable 'conv3_2_3x3/kernel:0' shape=(3, 3, 128, 128) dtype=float32>
# It is possible that this is intended behavior, but it is more likely
# an omission. This is a strong indication that this layer should be
# formulated as a subclassed Layer rather than a Lambda layer.
# WARNING:tensorflow:
# The following Variables were used a Lambda layer's call (tf.compat.v1.nn.fused_batch_norm_440), but
# are not present in its tracked objects:
#   <tf.Variable 'conv3_2_3x3/bn/gamma:0' shape=(128,) dtype=float32>
#   <tf.Variable 'conv3_2_3x3/bn/beta:0' shape=(128,) dtype=float32>
# It is possible that this is intended behavior, but it is more likely
# an omission. This is a strong indication that this layer should be
# formulated as a subclassed Layer rather than a Lambda layer.
# WARNING:tensorflow:
# The following Variables were used a Lambda layer's call (tf.nn.convolution_571), but
# are not present in its tracked objects:
#   <tf.Variable 'conv3_2_1x1_increase/kernel:0' shape=(1, 1, 128, 512) dtype=float32>
# It is possible that this is intended behavior, but it is more likely
# an omission. This is a strong indication that this layer should be
# formulated as a subclassed Layer rather than a Lambda layer.
# WARNING:tensorflow:
# The following Variables were used a Lambda layer's call (tf.compat.v1.nn.fused_batch_norm_441), but
# are not present in its tracked objects:
#   <tf.Variable 'conv3_2_1x1_increase/bn/gamma:0' shape=(512,) dtype=float32>
#   <tf.Variable 'conv3_2_1x1_increase/bn/beta:0' shape=(512,) dtype=float32>
# It is possible that this is intended behavior, but it is more likely
# an omission. This is a strong indication that this layer should be
# formulated as a subclassed Layer rather than a Lambda layer.
# WARNING:tensorflow:
# The following Variables were used a Lambda layer's call (tf.nn.convolution_572), but
# are not present in its tracked objects:
#   <tf.Variable 'conv3_3_1x1_reduce/kernel:0' shape=(1, 1, 512, 128) dtype=float32>
# It is possible that this is intended behavior, but it is more likely
# an omission. This is a strong indication that this layer should be
# formulated as a subclassed Layer rather than a Lambda layer.
# WARNING:tensorflow:
# The following Variables were used a Lambda layer's call (tf.compat.v1.nn.fused_batch_norm_442), but
# are not present in its tracked objects:
#   <tf.Variable 'conv3_3_1x1_reduce/bn/gamma:0' shape=(128,) dtype=float32>
#   <tf.Variable 'conv3_3_1x1_reduce/bn/beta:0' shape=(128,) dtype=float32>
# It is possible that this is intended behavior, but it is more likely
# an omission. This is a strong indication that this layer should be
# formulated as a subclassed Layer rather than a Lambda layer.
# WARNING:tensorflow:
# The following Variables were used a Lambda layer's call (tf.nn.convolution_573), but
# are not present in its tracked objects:
#   <tf.Variable 'conv3_3_3x3/kernel:0' shape=(3, 3, 128, 128) dtype=float32>
# It is possible that this is intended behavior, but it is more likely
# an omission. This is a strong indication that this layer should be
# formulated as a subclassed Layer rather than a Lambda layer.
# WARNING:tensorflow:
# The following Variables were used a Lambda layer's call (tf.compat.v1.nn.fused_batch_norm_443), but
# are not present in its tracked objects:
#   <tf.Variable 'conv3_3_3x3/bn/gamma:0' shape=(128,) dtype=float32>
#   <tf.Variable 'conv3_3_3x3/bn/beta:0' shape=(128,) dtype=float32>
# It is possible that this is intended behavior, but it is more likely
# an omission. This is a strong indication that this layer should be
# formulated as a subclassed Layer rather than a Lambda layer.
# WARNING:tensorflow:
# The following Variables were used a Lambda layer's call (tf.nn.convolution_574), but
# are not present in its tracked objects:
#   <tf.Variable 'conv3_3_1x1_increase/kernel:0' shape=(1, 1, 128, 512) dtype=float32>
# It is possible that this is intended behavior, but it is more likely
# an omission. This is a strong indication that this layer should be
# formulated as a subclassed Layer rather than a Lambda layer.
# WARNING:tensorflow:
# The following Variables were used a Lambda layer's call (tf.compat.v1.nn.fused_batch_norm_444), but
# are not present in its tracked objects:
#   <tf.Variable 'conv3_3_1x1_increase/bn/gamma:0' shape=(512,) dtype=float32>
#   <tf.Variable 'conv3_3_1x1_increase/bn/beta:0' shape=(512,) dtype=float32>
# It is possible that this is intended behavior, but it is more likely
# an omission. This is a strong indication that this layer should be
# formulated as a subclassed Layer rather than a Lambda layer.
# WARNING:tensorflow:
# The following Variables were used a Lambda layer's call (tf.nn.convolution_575), but
# are not present in its tracked objects:
#   <tf.Variable 'conv3_4_1x1_reduce/kernel:0' shape=(1, 1, 512, 128) dtype=float32>
# It is possible that this is intended behavior, but it is more likely
# an omission. This is a strong indication that this layer should be
# formulated as a subclassed Layer rather than a Lambda layer.
# WARNING:tensorflow:
# The following Variables were used a Lambda layer's call (tf.compat.v1.nn.fused_batch_norm_445), but
# are not present in its tracked objects:
#   <tf.Variable 'conv3_4_1x1_reduce/bn/gamma:0' shape=(128,) dtype=float32>
#   <tf.Variable 'conv3_4_1x1_reduce/bn/beta:0' shape=(128,) dtype=float32>
# It is possible that this is intended behavior, but it is more likely
# an omission. This is a strong indication that this layer should be
# formulated as a subclassed Layer rather than a Lambda layer.
# WARNING:tensorflow:
# The following Variables were used a Lambda layer's call (tf.nn.convolution_576), but
# are not present in its tracked objects:
#   <tf.Variable 'conv3_4_3x3/kernel:0' shape=(3, 3, 128, 128) dtype=float32>
# It is possible that this is intended behavior, but it is more likely
# an omission. This is a strong indication that this layer should be
# formulated as a subclassed Layer rather than a Lambda layer.
# WARNING:tensorflow:
# The following Variables were used a Lambda layer's call (tf.compat.v1.nn.fused_batch_norm_446), but
# are not present in its tracked objects:
#   <tf.Variable 'conv3_4_3x3/bn/gamma:0' shape=(128,) dtype=float32>
#   <tf.Variable 'conv3_4_3x3/bn/beta:0' shape=(128,) dtype=float32>
# It is possible that this is intended behavior, but it is more likely
# an omission. This is a strong indication that this layer should be
# formulated as a subclassed Layer rather than a Lambda layer.
# WARNING:tensorflow:
# The following Variables were used a Lambda layer's call (tf.nn.convolution_577), but
# are not present in its tracked objects:
#   <tf.Variable 'conv3_4_1x1_increase/kernel:0' shape=(1, 1, 128, 512) dtype=float32>
# It is possible that this is intended behavior, but it is more likely
# an omission. This is a strong indication that this layer should be
# formulated as a subclassed Layer rather than a Lambda layer.
# WARNING:tensorflow:
# The following Variables were used a Lambda layer's call (tf.compat.v1.nn.fused_batch_norm_447), but
# are not present in its tracked objects:
#   <tf.Variable 'conv3_4_1x1_increase/bn/gamma:0' shape=(512,) dtype=float32>
#   <tf.Variable 'conv3_4_1x1_increase/bn/beta:0' shape=(512,) dtype=float32>
# It is possible that this is intended behavior, but it is more likely
# an omission. This is a strong indication that this layer should be
# formulated as a subclassed Layer rather than a Lambda layer.
# WARNING:tensorflow:
# The following Variables were used a Lambda layer's call (tf.nn.convolution_578), but
# are not present in its tracked objects:
#   <tf.Variable 'conv4_1_1x1_reduce/kernel:0' shape=(1, 1, 512, 256) dtype=float32>
# It is possible that this is intended behavior, but it is more likely
# an omission. This is a strong indication that this layer should be
# formulated as a subclassed Layer rather than a Lambda layer.
# WARNING:tensorflow:
# The following Variables were used a Lambda layer's call (tf.compat.v1.nn.fused_batch_norm_448), but
# are not present in its tracked objects:
#   <tf.Variable 'conv4_1_1x1_reduce/bn/gamma:0' shape=(256,) dtype=float32>
#   <tf.Variable 'conv4_1_1x1_reduce/bn/beta:0' shape=(256,) dtype=float32>
# It is possible that this is intended behavior, but it is more likely
# an omission. This is a strong indication that this layer should be
# formulated as a subclassed Layer rather than a Lambda layer.
# WARNING:tensorflow:
# The following Variables were used a Lambda layer's call (tf.nn.convolution_579), but
# are not present in its tracked objects:
#   <tf.Variable 'conv4_1_3x3/kernel:0' shape=(3, 3, 256, 256) dtype=float32>
# It is possible that this is intended behavior, but it is more likely
# an omission. This is a strong indication that this layer should be
# formulated as a subclassed Layer rather than a Lambda layer.
# WARNING:tensorflow:
# The following Variables were used a Lambda layer's call (tf.compat.v1.nn.fused_batch_norm_449), but
# are not present in its tracked objects:
#   <tf.Variable 'conv4_1_3x3/bn/gamma:0' shape=(256,) dtype=float32>
#   <tf.Variable 'conv4_1_3x3/bn/beta:0' shape=(256,) dtype=float32>
# It is possible that this is intended behavior, but it is more likely
# an omission. This is a strong indication that this layer should be
# formulated as a subclassed Layer rather than a Lambda layer.
# WARNING:tensorflow:
# The following Variables were used a Lambda layer's call (tf.nn.convolution_580), but
# are not present in its tracked objects:
#   <tf.Variable 'conv4_1_1x1_proj/kernel:0' shape=(1, 1, 512, 1024) dtype=float32>
# It is possible that this is intended behavior, but it is more likely
# an omission. This is a strong indication that this layer should be
# formulated as a subclassed Layer rather than a Lambda layer.
# WARNING:tensorflow:
# The following Variables were used a Lambda layer's call (tf.nn.convolution_581), but
# are not present in its tracked objects:
#   <tf.Variable 'conv4_1_1x1_increase/kernel:0' shape=(1, 1, 256, 1024) dtype=float32>
# It is possible that this is intended behavior, but it is more likely
# an omission. This is a strong indication that this layer should be
# formulated as a subclassed Layer rather than a Lambda layer.
# WARNING:tensorflow:
# The following Variables were used a Lambda layer's call (tf.compat.v1.nn.fused_batch_norm_450), but
# are not present in its tracked objects:
#   <tf.Variable 'conv4_1_1x1_increase/bn/gamma:0' shape=(1024,) dtype=float32>
#   <tf.Variable 'conv4_1_1x1_increase/bn/beta:0' shape=(1024,) dtype=float32>
# It is possible that this is intended behavior, but it is more likely
# an omission. This is a strong indication that this layer should be
# formulated as a subclassed Layer rather than a Lambda layer.
# WARNING:tensorflow:
# The following Variables were used a Lambda layer's call (tf.compat.v1.nn.fused_batch_norm_451), but
# are not present in its tracked objects:
#   <tf.Variable 'conv4_1_1x1_proj/bn/gamma:0' shape=(1024,) dtype=float32>
#   <tf.Variable 'conv4_1_1x1_proj/bn/beta:0' shape=(1024,) dtype=float32>
# It is possible that this is intended behavior, but it is more likely
# an omission. This is a strong indication that this layer should be
# formulated as a subclassed Layer rather than a Lambda layer.
# WARNING:tensorflow:
# The following Variables were used a Lambda layer's call (tf.nn.convolution_582), but
# are not present in its tracked objects:
#   <tf.Variable 'conv4_2_1x1_reduce/kernel:0' shape=(1, 1, 1024, 256) dtype=float32>
# It is possible that this is intended behavior, but it is more likely
# an omission. This is a strong indication that this layer should be
# formulated as a subclassed Layer rather than a Lambda layer.
# WARNING:tensorflow:
# The following Variables were used a Lambda layer's call (tf.compat.v1.nn.fused_batch_norm_452), but
# are not present in its tracked objects:
#   <tf.Variable 'conv4_2_1x1_reduce/bn/gamma:0' shape=(256,) dtype=float32>
#   <tf.Variable 'conv4_2_1x1_reduce/bn/beta:0' shape=(256,) dtype=float32>
# It is possible that this is intended behavior, but it is more likely
# an omission. This is a strong indication that this layer should be
# formulated as a subclassed Layer rather than a Lambda layer.
# WARNING:tensorflow:
# ...
# tf.nn.relu_616 (TFOpLambda)     (None, 7, 7, 2048)   0           tf.__operators__.add_158[0][0]
# __________________________________________________________________________________________________
# tf.compat.v1.nn.max_pool_51 (TF (None, 14, 14, 512)  0           tf.nn.relu_505[0][0]
# __________________________________________________________________________________________________
# tf.compat.v1.nn.max_pool_56 (TF (None, 14, 14, 512)  0           tf.nn.relu_518[0][0]
# __________________________________________________________________________________________________
# tf.nn.convolution_604 (TFOpLamb (None, 7, 7, 512)    0           tf.nn.relu_567[0][0]
# __________________________________________________________________________________________________
# tf.nn.convolution_657 (TFOpLamb (None, 7, 7, 512)    0           tf.nn.relu_616[0][0]
# __________________________________________________________________________________________________
# tf.nn.convolution_538 (TFOpLamb (None, 14, 14, 512)  0           tf.compat.v1.nn.max_pool_51[0][0]
# __________________________________________________________________________________________________
# tf.nn.convolution_551 (TFOpLamb (None, 14, 14, 512)  0           tf.compat.v1.nn.max_pool_56[0][0]
# __________________________________________________________________________________________________
# tf.compat.v1.nn.fused_batch_nor ((None, 7, 7, 512),  0           tf.nn.convolution_604[0][0]
# __________________________________________________________________________________________________
# tf.compat.v1.nn.fused_batch_nor ((None, 7, 7, 512),  0           tf.nn.convolution_657[0][0]
# __________________________________________________________________________________________________
# tf.nn.bias_add_114 (TFOpLambda) (None, 14, 14, 512)  0           tf.nn.convolution_538[0][0]
# __________________________________________________________________________________________________
# tf.nn.bias_add_127 (TFOpLambda) (None, 14, 14, 512)  0           tf.nn.convolution_551[0][0]
# __________________________________________________________________________________________________
# tf.nn.relu_568 (TFOpLambda)     (None, 7, 7, 512)    0           tf.compat.v1.nn.fused_batch_norm_
# __________________________________________________________________________________________________
# tf.nn.relu_617 (TFOpLambda)     (None, 7, 7, 512)    0           tf.compat.v1.nn.fused_batch_norm_
# __________________________________________________________________________________________________
# tf.nn.relu_506 (TFOpLambda)     (None, 14, 14, 512)  0           tf.nn.bias_add_114[0][0]
# __________________________________________________________________________________________________
# tf.nn.relu_519 (TFOpLambda)     (None, 14, 14, 512)  0           tf.nn.bias_add_127[0][0]
# __________________________________________________________________________________________________
# tf.nn.convolution_605 (TFOpLamb (None, 7, 7, 512)    0           tf.nn.relu_568[0][0]
# __________________________________________________________________________________________________
# tf.nn.convolution_658 (TFOpLamb (None, 7, 7, 512)    0           tf.nn.relu_617[0][0]
# __________________________________________________________________________________________________
# tf.nn.convolution_539 (TFOpLamb (None, 14, 14, 512)  0           tf.nn.relu_506[0][0]
# __________________________________________________________________________________________________
# tf.nn.convolution_552 (TFOpLamb (None, 14, 14, 512)  0           tf.nn.relu_519[0][0]
# __________________________________________________________________________________________________
# tf.compat.v1.nn.fused_batch_nor ((None, 7, 7, 512),  0           tf.nn.convolution_605[0][0]
# __________________________________________________________________________________________________
# tf.compat.v1.nn.fused_batch_nor ((None, 7, 7, 512),  0           tf.nn.convolution_658[0][0]
# __________________________________________________________________________________________________
# tf.nn.bias_add_115 (TFOpLambda) (None, 14, 14, 512)  0           tf.nn.convolution_539[0][0]
# __________________________________________________________________________________________________
# tf.nn.bias_add_128 (TFOpLambda) (None, 14, 14, 512)  0           tf.nn.convolution_552[0][0]
# __________________________________________________________________________________________________
# tf.nn.relu_569 (TFOpLambda)     (None, 7, 7, 512)    0           tf.compat.v1.nn.fused_batch_norm_
# __________________________________________________________________________________________________
# tf.nn.relu_618 (TFOpLambda)     (None, 7, 7, 512)    0           tf.compat.v1.nn.fused_batch_norm_
# __________________________________________________________________________________________________
# tf.nn.relu_507 (TFOpLambda)     (None, 14, 14, 512)  0           tf.nn.bias_add_115[0][0]
# __________________________________________________________________________________________________
# tf.nn.relu_520 (TFOpLambda)     (None, 14, 14, 512)  0           tf.nn.bias_add_128[0][0]
# __________________________________________________________________________________________________
# tf.nn.convolution_606 (TFOpLamb (None, 7, 7, 2048)   0           tf.nn.relu_569[0][0]
# __________________________________________________________________________________________________
# tf.nn.convolution_659 (TFOpLamb (None, 7, 7, 2048)   0           tf.nn.relu_618[0][0]
# __________________________________________________________________________________________________
# tf.nn.convolution_540 (TFOpLamb (None, 14, 14, 512)  0           tf.nn.relu_507[0][0]
# __________________________________________________________________________________________________
# tf.nn.convolution_553 (TFOpLamb (None, 14, 14, 512)  0           tf.nn.relu_520[0][0]
# __________________________________________________________________________________________________
# tf.compat.v1.nn.fused_batch_nor ((None, 7, 7, 2048), 0           tf.nn.convolution_606[0][0]
# __________________________________________________________________________________________________
# tf.compat.v1.nn.fused_batch_nor ((None, 7, 7, 2048), 0           tf.nn.convolution_659[0][0]
# __________________________________________________________________________________________________
# tf.nn.bias_add_116 (TFOpLambda) (None, 14, 14, 512)  0           tf.nn.convolution_540[0][0]
# __________________________________________________________________________________________________
# tf.nn.bias_add_129 (TFOpLambda) (None, 14, 14, 512)  0           tf.nn.convolution_553[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_143 (TFOpL (None, 7, 7, 2048)   0           tf.compat.v1.nn.fused_batch_norm_
#                                                                  tf.nn.relu_567[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_159 (TFOpL (None, 7, 7, 2048)   0           tf.compat.v1.nn.fused_batch_norm_
#                                                                  tf.nn.relu_616[0][0]
# __________________________________________________________________________________________________
# tf.nn.relu_508 (TFOpLambda)     (None, 14, 14, 512)  0           tf.nn.bias_add_116[0][0]
# __________________________________________________________________________________________________
# tf.nn.relu_521 (TFOpLambda)     (None, 14, 14, 512)  0           tf.nn.bias_add_129[0][0]
# __________________________________________________________________________________________________
# tf.nn.relu_570 (TFOpLambda)     (None, 7, 7, 2048)   0           tf.__operators__.add_143[0][0]
# __________________________________________________________________________________________________
# tf.nn.relu_619 (TFOpLambda)     (None, 7, 7, 2048)   0           tf.__operators__.add_159[0][0]
# __________________________________________________________________________________________________
# tf.compat.v1.nn.max_pool_52 (TF (None, 7, 7, 512)    0           tf.nn.relu_508[0][0]
# __________________________________________________________________________________________________
# tf.compat.v1.nn.max_pool_57 (TF (None, 7, 7, 512)    0           tf.nn.relu_521[0][0]
# __________________________________________________________________________________________________
# tf.compat.v1.nn.avg_pool_8 (TFO (None, 1, 1, 2048)   0           tf.nn.relu_570[0][0]
# __________________________________________________________________________________________________
# tf.compat.v1.nn.avg_pool_9 (TFO (None, 1, 1, 2048)   0           tf.nn.relu_619[0][0]
# __________________________________________________________________________________________________
# global_max_pooling2d_16 (Global (None, 512)          0           tf.compat.v1.nn.max_pool_52[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_16 (Gl (None, 512)          0           tf.compat.v1.nn.max_pool_52[0][0]
# __________________________________________________________________________________________________
# global_max_pooling2d_17 (Global (None, 512)          0           tf.compat.v1.nn.max_pool_57[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_17 (Gl (None, 512)          0           tf.compat.v1.nn.max_pool_57[0][0]
# __________________________________________________________________________________________________
# global_max_pooling2d_18 (Global (None, 2048)         0           tf.compat.v1.nn.avg_pool_8[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_18 (Gl (None, 2048)         0           tf.compat.v1.nn.avg_pool_8[0][0]
# __________________________________________________________________________________________________
# global_max_pooling2d_19 (Global (None, 2048)         0           tf.compat.v1.nn.avg_pool_9[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_19 (Gl (None, 2048)         0           tf.compat.v1.nn.avg_pool_9[0][0]
# __________________________________________________________________________________________________
# concatenate_28 (Concatenate)    (None, 1024)         0           global_max_pooling2d_16[0][0]
#                                                                  global_average_pooling2d_16[0][0]
# __________________________________________________________________________________________________
# concatenate_29 (Concatenate)    (None, 1024)         0           global_max_pooling2d_17[0][0]
#                                                                  global_average_pooling2d_17[0][0]
# __________________________________________________________________________________________________
# concatenate_31 (Concatenate)    (None, 4096)         0           global_max_pooling2d_18[0][0]
#                                                                  global_average_pooling2d_18[0][0]
# __________________________________________________________________________________________________
# concatenate_32 (Concatenate)    (None, 4096)         0           global_max_pooling2d_19[0][0]
#                                                                  global_average_pooling2d_19[0][0]
# __________________________________________________________________________________________________
# subtract_12 (Subtract)          (None, 1024)         0           concatenate_28[0][0]
#                                                                  concatenate_29[0][0]
# __________________________________________________________________________________________________
# multiply_23 (Multiply)          (None, 4096)         0           concatenate_31[0][0]
#                                                                  concatenate_31[0][0]
# __________________________________________________________________________________________________
# multiply_24 (Multiply)          (None, 4096)         0           concatenate_32[0][0]
#                                                                  concatenate_32[0][0]
# __________________________________________________________________________________________________
# subtract_13 (Subtract)          (None, 4096)         0           concatenate_32[0][0]
#                                                                  concatenate_32[0][0]
# __________________________________________________________________________________________________
# multiply_21 (Multiply)          (None, 1024)         0           concatenate_28[0][0]
#                                                                  concatenate_29[0][0]
# __________________________________________________________________________________________________
# multiply_20 (Multiply)          (None, 1024)         0           subtract_12[0][0]
#                                                                  subtract_12[0][0]
# __________________________________________________________________________________________________
# subtract_14 (Subtract)          (None, 4096)         0           multiply_23[0][0]
#                                                                  multiply_24[0][0]
# __________________________________________________________________________________________________
# multiply_22 (Multiply)          (None, 4096)         0           subtract_13[0][0]
#                                                                  subtract_13[0][0]
# __________________________________________________________________________________________________
# concatenate_30 (Concatenate)    (None, 2048)         0           multiply_21[0][0]
#                                                                  multiply_20[0][0]
# __________________________________________________________________________________________________
# concatenate_33 (Concatenate)    (None, 8192)         0           subtract_14[0][0]
#                                                                  multiply_22[0][0]
# __________________________________________________________________________________________________
# concatenate_34 (Concatenate)    (None, 10240)        0           concatenate_30[0][0]
#                                                                  concatenate_33[0][0]
# __________________________________________________________________________________________________
# dense_8 (Dense)                 (None, 200)          2048200     concatenate_34[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 200)          0           dense_8[0][0]
# __________________________________________________________________________________________________
# dense_9 (Dense)                 (None, 1)            201         dropout_4[0][0]
# ==================================================================================================
# Total params: 2,048,401
# Trainable params: 2,048,401
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
model.fit(gen(train, train_person_to_images_map, batch_size=16), use_multiprocessing=False,
                validation_data=gen(val, val_person_to_images_map, batch_size=16), epochs=25, verbose=1,
                workers=1, callbacks=callbacks_list, steps_per_epoch=100, validation_steps=50)
# Out:
# Epoch 1/25
#   7/100 [=>............................] - ETA: 1:34:49 - loss: 752.4706 - acc: 0.4826
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-38-a5b15cc0735e> in <module>()
#       1 model.fit(gen(train, train_person_to_images_map, batch_size=16), use_multiprocessing=False,
#       2                 validation_data=gen(val, val_person_to_images_map, batch_size=16), epochs=25, verbose=1,
# ----> 3                 workers=1, callbacks=callbacks_list, steps_per_epoch=100, validation_steps=50)
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1181                 _r=1):
#    1182               callbacks.on_train_batch_begin(step)
# -> 1183               tmp_logs = self.train_function(iterator)
#    1184               if data_handler.should_sync:
#    1185                 context.async_wait()
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/def_function.py in __call__(self, *args, **kwds)
#     887
#     888       with OptionalXlaContext(self._jit_compile):
# --> 889         result = self._call(*args, **kwds)
#     890
#     891       new_tracing_count = self.experimental_get_tracing_count()
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/def_function.py in _call(self, *args, **kwds)
#     915       # In this case we have created variables on the first call, so we run the
#     916       # defunned version which is guaranteed to never create variables.
# --> 917       return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     918     elif self._stateful_fn is not None:
#     919       # Release the lock early so that multiple threads can perform the call
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/function.py in __call__(self, *args, **kwargs)
#    3022        filtered_flat_args) = self._maybe_define_function(args, kwargs)
#    3023     return graph_function._call_flat(
# -> 3024         filtered_flat_args, captured_inputs=graph_function.captured_inputs)  # pylint: disable=protected-access
#    3025
#    3026   @property
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1959       # No tape is watching; skip to running the function.
#    1960       return self._build_call_outputs(self._inference_function.call(
# -> 1961           ctx, args, cancellation_manager=cancellation_manager))
#    1962     forward_backward = self._select_forward_and_backward_functions(
#    1963         args,
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/function.py in call(self, ctx, args, cancellation_manager)
#     594               inputs=args,
#     595               attrs=attrs,
# --> 596               ctx=ctx)
#     597         else:
#     598           outputs = execute.execute_with_cancellation(
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      58     ctx.ensure_initialized()
#      59     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
# ---> 60                                         inputs, attrs, num_outputs)
#      61   except core._NotOkStatusException as e:
#      62     if name is not None:
#
# KeyboardInterrupt:

# %%
# Modify paths as per your need
test_path = "/gdrive/MyDrive/Kinship Recognition Starter/test/"

#model = baseline_model()
#model.load_weights("/gdrive/MyDrive/vgg_face.h5")

submission = pd.read_csv('/gdrive/MyDrive/Kinship Recognition Starter/test_ds.csv')
predictions = []

for i in range(0, len(submission.p1.values), 32):
    if i%32 == 0:
      print(i)
    X1 = submission.p1.values[i:i+32]
    X1 = np.array([read_img(test_path + x) for x in X1])

    X1a = submission.p1.values[i:i+32]
    X1a = np.array([read_img(test_path + x) for x in X1a])

    X2 = submission.p2.values[i:i+32]
    X2 = np.array([read_img(test_path + x) for x in X2])

    X2a = submission.p2.values[i:i+32]
    X2a = np.array([read_img(test_path + x) for x in X2a])

    pred = model.predict([X1, X2, X1a, X2a]).ravel().tolist()
    predictions += pred
# Out:
# 0
# 32
# 64
# 96
# 128
# 160
# 192
# 224
# 256
# 288
# 320
# 352
# 384
# 416
# 448
# 480
# 512
# 544
# 576
# 608
# 640
# 672
# 704
# 736
# 768
# 800
# 832
# 864
# 896
# 928
# 960
# 992
# 1024
# 1056
# 1088
# 1120
# 1152
# 1184
# 1216
# 1248
# 1280
# 1312
# 1344
# 1376
# 1408
# 1440
# 1472
# 1504
# 1536
# 1568
# 1600
# 1632
# 1664
# 1696
# 1728
# 1760
# 1792
# 1824
# 1856
# 1888
# 1920
# 1952
# 1984
# 2016
# 2048
# 2080
# 2112
# 2144
# 2176
# 2208
# 2240
# 2272
# 2304
# 2336
# 2368
# 2400
# 2432
# 2464
# 2496
# 2528
# 2560
# 2592
# 2624
# 2656
# 2688
# 2720
# 2752
# 2784
# 2816
# 2848
# 2880
# 2912
# 2944
# 2976

# %%
# !pip list | grep tensorflow
# Out:
# tensorflow                    2.5.0
# tensorflow-datasets           4.0.1
# tensorflow-estimator          2.5.0
# tensorflow-gcs-config         2.5.0
# tensorflow-hub                0.12.0
# tensorflow-metadata           1.2.0
# tensorflow-probability        0.13.0

# %% [markdown]
# The final predictions will need to be rounded: EG 0.01 rounded to 0 and 0.78 rounded to 1. The simple .round() function is sufficient as below.

# %%
d = {'index': np.arange(0, 3000, 1), 'label':predictions}
submissionfile = pd.DataFrame(data=d)
submissionfile = submissionfile.round()
submissionfile.astype("int64").to_csv("/gdrive/MyDrive/tojo2.csv", index=False)

# %% [markdown]
# At this point, download the CSV and submit it on Kaggle to score your predictions.

# %%
while True: pass
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-b16dc615ea65> in <module>()
# ----> 1 while True: pass
#
# KeyboardInterrupt:
